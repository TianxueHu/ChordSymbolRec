# %%
from music21 import *
import os

# %%
os.chdir("../../datasets/final_dataset_140/music")

# %%
s = converter.parse('001.mid')
s.show()

# %%
#split into four parts
s.parts[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-dee6868ca564> in <module>
# ----> 1 s.parts[3]
#
# /opt/anaconda3/lib/python3.7/site-packages/music21/stream/iterator.py in __getitem__(self, k)
#     326         fe = self.matchingElements()
#     327         try:
# --> 328             e = fe[k]
#     329         except TypeError:
#     330             e = None
#
# IndexError: list index out of range

# %%
chord = s.chordify()
for c in chord:
    #print(c.duration.quarterLength)
    print(c.beat)
chord.show('text', addEndTimes=True)
# Out:
# 1.0
# 1.0
# 1.0
# 1.0
# 2.0
# 3.0
# 1.0
# 1.5
# 2.0
# 3.0
# 1.0
# 1.5
# 2.0
# 3.0
# 3.5
# 1.0
# 1.5
# 2.0
# 3.0
# 2.0
# 3.0
# 1.0
# 2.0
# 3.0
# 1.0
# 2.0
# 2.5
# 3.0
# 2.0
# 3.0
# 3.5
# 1.0
# 1.5
# 2.0
# 2.5
# 3.0
# 3.5
# 1.0
# 1.5
# 2.0
# 3.0
# 2.0
# 3.0
# 1.0
# 1.5
# 2.0
# 3.0
# 1.0
# 1.5
# 2.0
# 2.5
# 3.0
# 3.5
# 1.0
# 2.0
# 3.0
# 2.0
# 3.0
# 3.5
# 1.0
# 1.5
# 2.0
# 3.0
# 1.0
# 2.0
# 2.5
# 3.0
# 3.5
# 1.0
# 1.5
# 2.0
# 2.5
# 3.0
# 2.0
# 3.0
# 1.0
# 2.0
# 2.5
# 3.0
# 3.5
# 1.0
# 2.0
# 2.5
# 3.0
# {0.0 - 0.0} <music21.tempo.MetronomeMark larghetto Quarter=60.0>
# {0.0 - 0.0} <music21.key.Key of C major>
# {0.0 - 0.0} <music21.meter.TimeSignature 3/4>
# {0.0 - 1.0} <music21.note.Rest rest>
# {1.0 - 2.0} <music21.chord.Chord C2 E3 G3 C4>
# {2.0 - 3.0} <music21.chord.Chord C3 E3 G3 C4>
# {3.0 - 3.5} <music21.chord.Chord A2 F3 A3 C4>
# {3.5 - 4.0} <music21.chord.Chord A2 E3 A3 C4>
# {4.0 - 5.0} <music21.chord.Chord B2 D3 G3 G4>
# {5.0 - 6.0} <music21.chord.Chord C3 G3 E4>
# ...

# %%
print(chord.recurse())
# Out:
# <music21.stream.iterator.RecursiveIterator for Part:0x11bacb750 @:0>

# %%
for thisChord in chord.recurse().getElementsByClass('Chord'):
    print(thisChord.measureNumber, thisChord.beatStr, thisChord)
# Out:
# None 2 <music21.chord.Chord C2 E3 G3 C4>
# None 3 <music21.chord.Chord C3 E3 G3 C4>
# None 1 <music21.chord.Chord A2 F3 A3 C4>
# None 1 1/2 <music21.chord.Chord A2 E3 A3 C4>
# None 2 <music21.chord.Chord B2 D3 G3 G4>
# None 3 <music21.chord.Chord C3 G3 E4>
# None 1 <music21.chord.Chord G2 B2 G3 E4>
# None 1 1/2 <music21.chord.Chord G2 B2 G3 D4>
# None 2 <music21.chord.Chord A2 C3 E3 C4>
# None 3 <music21.chord.Chord F2 F3 A3 C4>
# None 3 1/2 <music21.chord.Chord F2 E3 G3 C4>
# None 1 <music21.chord.Chord E2 F3 A3 C4>
# None 1 1/2 <music21.chord.Chord D2 F3 B3 D4>
# None 2 <music21.chord.Chord C2 G3 C4 E4>
# None 3 <music21.chord.Chord G2 G3 B3 D4>
# None 2 <music21.chord.Chord C2 G3 C4 E4>
# None 3 <music21.chord.Chord B1 D3 G3 G4>
# None 1 <music21.chord.Chord C2 E3 A3 G4>
# None 2 <music21.chord.Chord D2 F3 B3 F4>
# None 3 <music21.chord.Chord E2 G3 C4 E4>
# None 1 <music21.chord.Chord F2 A3 C4 D4>
# None 2 <music21.chord.Chord G2 G3 B3 D4>
# ...
