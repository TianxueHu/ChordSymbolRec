# %%
import os
import pandas as pd
import numpy as np
from utils import to_21d_vec, get_beat_vector, specialChords, specialChordsABC
import re
import sys
sys.path.insert(1, './harmalysis')
from inputRN2Chord import inputRN
# Out:
# bII6

# %%
script_dir = os.getcwd()
score_rel_path = "../datasets/ABC/ABC_reduced_score_for_vec/n08op59-2_04_score_reduced4_tmp_vector_pre.krn"
scorepath = os.path.join(script_dir, score_rel_path)

# %%
df = pd.read_csv(scorepath, sep="\t", header=None)
pd.set_option('display.max_rows', df.shape[0]+1)
#df.columns = ["harm", "root", "voice4", "voice3", "voice2", "voice1", "index", "beat", "measure", "key", "meter" ]
#df.columns = ["harm", "root", "voice4", "voice3", "voice2", "voice1", "beat", "measure", "key", "meter" ]
#df.columns = ["harm", "voice4", "voice3", "voice2", "voice1", "index", "beat", "measure", "key", "meter" ]
#df.columns = ["harm", "voice4", "voice3", "voice2", "voice1", "beat", "measure", "key", "meter" ]

#sear org
#df.columns = ["voice4", "voice3", "voice2", "voice1", "harm", "beat", "measure", "key", "meter" ]

# abc org
#df.columns = ["voice4", "dy4", "voice3", "dy3", "voice2", "dy2", "voice1", "dy1",
#              "harm", "beat", "measure", "key", "meter" ]
# abc reduce
df.columns = ["voice4", "dy4", "voice3", "dy3", "voice2", "dy2", "voice1", "dy1",
              "harm", "index", "beat", "measure", "key", "meter" ]

# %%
# process dataframe, delete bars, score representations, and "rest slice"
df = df[~df['beat'].astype(str).str.startswith(('=','.','*'))]
df
# Out:
#        voice4      dy4   voice3    dy3        voice2      dy2        voice1  \
# 2        4CC'       fp      4E'     fp           4G'       fp           2.c
# 4         8C'       fp      8E'     fp           8G'       fp           2.c
# 5         4C'       fp      4E'     fp           4G'       fp           2.c
# 6          8r       fp       8r     fp            8r       fp        (8cccL
# 7         8C'       fp      8E'     fp           8G'       fp            8r
# 9          4C       fp       4E     fp            4G       fp        4eee')
# 11         8C       fp       8E     fp            8G       fp            8r
# 12         4C       fp      4Fn     fp            4A       fp         4ccc'
# 14         8C       fp       8F     fp            8r       fp          8aa'
# 16         4C       fp       4E     fp            4c       fp          2.gg
# 18         8C       fp       8E     fp            8G       fp          2.gg
# 19         4C       fp       4E     fp            4G       fp          2.gg
# 20         8r       fp       8r     fp            8r       fp        (8cccL
# 21         8C       fp       8E     fp            8G       fp            8r
# 23         4C       fp       4E     fp            4G       fp         8eeeL
# 25         8r       fp       8r     fp            8r       fp         8ccc'
# 26         8C       fp       8E     fp            8G       fp         8bb'J
# 27         4C       fp      4Fn     fp            4A       fp        (8dddL
# 29         8r       fp       8r     fp            8r       fp          8bb'
# 30         8C       fp       8F     fp            8r       fp            8r
# 32         4C       fp       4E     fp            4c       fp          [2gg
# 34         8C       fp       8E     fp            8G       fp          [2gg
# 35         4C       fp       4E     fp            4G       fp         4.gg]
# 37         8C       fp       8E     fp            8G       fp            8r
# 39         4C       fp       4E     fp            4G       fp          4ee'
# 41         8C       fp       8E     fp            8G       fp            8r
# 42         4C       fp       4E     fp            4G       fp          4cc'
# 126        8r       fp       8r     fp            8r       fp        8ff#XL
# 127        8B       fp      8f#     fp            8a       fp        8dd#J)
# 129        4e       fp       4B     fp            4g       fp          2ee`
# 131        8E       fp       8B     fp            8e       fp          2ee`
# 132        4E       fp       4B     fp            4e       fp          2gg`
# 134        8E       fp       8B     fp            8e       fp          2gg`
# 136       4F#    fp fp     4A#X     fp          4c#X    fp fp         2.ff#
# 138       8F#    fp fp      8A#     fp           8c#    fp fp         2.ff#
# 139       4F#    fp fp      4A#     fp           4c#    fp fp         2.ff#
# 140        8r    fp fp       8r     fp            8r    fp fp       4ccc#X'
# 141       8F#    fp fp      8A#     fp           8c#    fp fp       4ccc#X'
# 143       4F#    fp fp     4A#X     fp          4c#X    fp fp      (8ccc#XL
# 144       4F#    fp fp     4A#X     fp          4c#X    fp fp       8aa#XJ)
# 145        8r    fp fp       8r     fp            8r    fp fp         4ff#'
# 146       8F#    fp fp      8A#     fp           8c#    fp fp         4ff#'
# 147       4F#    fp fp      4A#     fp           4c#    fp fp         4ff#'
# 148        8r    fp fp       8r     fp            8r    fp fp         4ff#'
# 149       8F#    fp fp      8A#     fp           8c#    fp fp         4ff#'
# 151      2F#`    fp fp    2A#X`     fp         2c#X`    fp fp         2ff#`
# 152       2D`    fp fp     2An`     fp          2f#`    fp fp        2cccn`
# 154       2G`    fp fp      2d`     fp          2fn`    fp fp          2bb`
# 155      2GG`    fp fp   2G` 2d     fp         2ffn`    fp fp          2bb`
# 157    4CC 4C       fp       4G     fp           4ee       fp         2.ccc
# 159    8CC 8C       fp       8G     fp            8e       fp         2.ccc
# 160    4CC 4C       fp       4G     fp            4e       fp         2.ccc
# 161        8r       fp       8r     fp            8r       fp        (8cccL
# 162    8CC 8C       fp       8G     fp            8e       fp            8r
# 164    4CC 4C       fp       4G     fp            4e       fp        4eee')
# 166    8CC 8C       fp       8G     fp            8e       fp            8r
# 167    4CC 4C       fp       4A     fp           4fn       fp         4ccc'
# 169    8CC 8C       fp       8r     fp            8f       fp          8aa'
# 171    4CC 4C       fp       4c     fp            4e       fp          2.gg
# 173    8CC 8C       fp       8G     fp            8e       fp          2.gg
# 174    4CC 4C       fp       4G     fp            4e       fp          2.gg
# 175        8r       fp       8r     fp            8r       fp        (8cccL
# 176    8CC 8C       fp       8G     fp            8e       fp            8r
# 178    4CC 4C       fp       4G     fp            4e       fp         8eeeL
# 180        8r       fp       8r     fp            8r       fp         8ccc'
# 181    8CC 8C       fp       8G     fp            8e       fp         8bb'J
# 182    4CC 4C       fp       4A     fp           4fn       fp        (8dddL
# 184        8r       fp       8r     fp            8r       fp          8bb'
# 185    8CC 8C       fp       8r     fp            8f       fp            8r
# 187    4CC 4C       fp       4c     fp            4e       fp          [2gg
# 189    8CC 8C       fp       8E     fp            8g       fp          [2gg
# 190    4CC 4C       fp       4E     fp            4g       fp         4.gg]
# 192    8CC 8C       fp       8r     fp            8r       fp            8r
# 194    4CC 4C       fp       4C     fp            4e       fp           4ee
# 196    8CC 8C       fp       8r     fp            8r       fp            8r
# 197    4CC 4C       fp       4E     fp            4c       fp           4cc
# 199    8CC 8C       fp       8E     fp            8r       fp            8r
# 201    8CC 8C       fp       8E     fp         8qqB/       fp         8qqb/
# 202    4CC 4C       fp       4E     fp           (4A       fp           (4a
# 203        8r       fp       8r     fp           8GL       fp           8gL
# 204    8CC 8C       fp       8E     fp            8r       fp            8r
# 205       4BB       fp    4E 4G     fp           [2B       fp           [2b
# 207       8BB       fp    8E 8G     fp           [2B       fp           [2b
# 209       4BB       fp   4F# 4A     fp           4B]       fp           4b]
# 210        8r       fp       8r     fp        (8c#XL       fp       (8cc#XL
# 211       8BB       fp   8F# 8A     fp            8r       fp            8r
# 212       4BB       fp   4F# 4A     fp            4e       fp           4ee
# 213        8r       fp       8r     fp         8f#XL       fp        8ff#XL
# 214       8BB       fp   8F# 8A     fp         8d#J)       fp        8dd#J)
# 216        4E       fp    4E 4G     fp            4e       fp          2ee`
# 218        8E       fp       8G     fp            8B       fp          2ee`
# 219        4E       fp       4B     fp            4e       fp          2gg`
# 221        8E       fp       8B     fp            8e       fp          2gg`
# 223      4F#X       fp     4A#X     fp          4c#X    fp fp         2.ff#
# 225       8F#       fp      8A#     fp           8c#    fp fp         2.ff#
# 226       4F#       fp      4A#     fp           4c#    fp fp         2.ff#
# 227        8r       fp       8r     fp            8r    fp fp       4ccc#X'
# 228       8F#       fp      8A#     fp           8c#    fp fp       4ccc#X'
# 230      4F#X       fp     4A#X     fp          4c#X    fp fp      (8ccc#XL
# 231      4F#X       fp     4A#X     fp          4c#X    fp fp       8aa#XJ)
# 232        8r       fp       8r     fp            8r    fp fp         4ff#'
# 233       8F#       fp      8A#     fp           8c#    fp fp         4ff#'
# 234       4F#       fp      4A#     fp           4c#    fp fp         4ff#'
# 235        8r       fp       8r     fp            8r    fp fp         4ff#'
# 236       8F#       fp      8A#     fp           8c#    fp fp         4ff#'
# 238      2F#`       fp    2A#X`     fp         2c#X`    fp fp         2ff#`
# 239       2D`       fp     2An`     fp          2f#`    fp fp        2cccn`
# 241       2G`       fp      2d`     fp          2fn`    fp fp          2bb`
# 242      2GG`       fp   2G` 2d     fp         2ffn`    fp fp          2bb`
# 244    4CC 4C       fp       4G     fp           4ee       fp         2.ccc
# 246    8CC 8C       fp    8E 8G     fp            8g       fp         2.ccc
# 247    4CC 4C       fp    4E 4G     fp            4g       fp         2.ccc
# 248        8r       fp       8r     fp            8r       fp        (8cccL
# 249    8CC 8C       fp    8E 8G     fp            8g       fp            8r
# 251    4CC 4C       fp    4E 4G     fp            4g       fp        4eee')
# 253    8CC 8C       fp    8E 8G     fp            8g       fp            8r
# 254    4CC 4C       fp   4Fn 4A     fp            4a       fp         4ccc'
# 256    8CC 8C       fp       8A     fp           8fn       fp          8aa'
# 258    4CC 4C       fp       4c     fp            4e       fp          2.gg
# 260    8CC 8C       fp    8E 8G     fp            8g       fp          2.gg
# 261    4CC 4C       fp    4E 4G     fp            4g       fp          2.gg
# 262        8r       fp       8r     fp            8r       fp        (8cccL
# 340       4GG        f      4Gn      f            4b        f          8ee)
# 342        4r        f       4B      f        4Gn 4e        f          (8bL
# 343        4r        f       4B      f        4Gn 4e        f        8dd#XJ
# 344        4G        f       4r      f            4r        f          8ee)
# 346        4r        f       4B      f         4G 4e        f          (8bL
# 347        4r        f       4B      f         4G 4e        f          8eeJ
# 349       4F#        f       4r      f            4r        f         8ff#)
# 351        4r        f     4d#X      f        4A 4f#        f          (8bL
# 352        4r        f     4d#X      f        4A 4f#        f         8ff#J
# 353        4E        f       4r      f            4r        f          8gg)
# 355        4r        f       4e      f         4B 4g        f         (8eeL
# 356        4r        f       4e      f         4B 4g        f          8ggJ
# 358        4C        f       4r      f            4r        f          8aa)
# 360        4r        f       4c      f         4e 4a        f         (8eeL
# 361        4r        f       4c      f         4e 4a        f          8aaJ
# 362       4BB        f       4r      f            4r        f          8bb)
# 364        4r        f     4g#X      f         4d 4b        f         (8eeL
# 365        4r        f     4g#X      f         4d 4b        f          8bbJ
# 367       4AA        f       4r      f            4r        f         8ccc)
# 369        4r        f       4a      f           4cc        f         (8aaL
# 370        4r        f       4a      f           4cc        f         8ff#J
# 371       4BB        f       4r      f            4r        f        8dd#X)
# 373        4r        f      4f#      f            4a        f          (8bL
# 374        4r        f      4f#      f            4a        f        8dd#J)
# 376       4EE        f       4B      f           4g'        f          8eeL
# 378        4r        f       4r      f            8r        f           8ee
# 380        2r        f       2r      f           4e'        f          8eeL
# 381        2r        f       2r      f           4e'        f           8gg
# 382        2r        f       2r      f            8r        f          8ff#
# 383        2r        f       2r      f           8B'        f            8r
# 385       4BB        f   4B 4f#      f            4a        f        8dd#XL
# 387        4r        f       4r      f            8r        f          8dd#
# 389        2r        f       2r      f           4f#        f         8dd#L
# 390        2r        f       2r      f           4f#        f          8ff#
# 391        2r        f       2r      f            8r        f           8ee
# 392        2r        f       2r      f            8B        f            8r
# 394        4E        f       4B      f            4g        f          8eeL
# 396        4r        f       4r      f            8r        f           8ee
# 398        2r        f       2r      f            4e        f          8eeL
# 399        2r        f       2r      f            4e        f           8gg
# 400        2r        f       2r      f            8r        f          8ff#
# 401        2r        f       2r      f            8B        f            8r
# 403       4BB        f   4F# 4B      f            4a        f        8dd#XL
# 405        4r        f       4r      f            8r        f          8ff#
# 407        2r        f       2r      f           4f#        f          8aaL
# 409        2r        f       2r      f            8r        f        8ccc#X
# 410        2r        f       2r      f            8B        f            8r
# 412        8E        f       8G      f            4g        f          4eee
# 414      (8EL        f     (8GL      f            4r        f            4r
# 416      8G')        f     8B')      f            2r        f            2r
# 418      (8AL        f     (8cL      f            2r        f            2r
# 421      8c')        f     8e')      f            1r        f            2r
# 423      (8cL        f     (8eL      f            1r        f            2r
# 425       2eT        f      2gT      f            1r        f        (2ccnT
# 427        4d        f      4f#      f          4ff#        f          8b')
# 429        4r        f       4r      f            8r        f          (8bL
# 431        2r        f       2r      f           4dd        f         8dd')
# 433        2r        f       2r      f            8r        f         (8ddL
# 434        2r        f       2r      f            8b        f            8r
# 436        1r        f       1r      f           4f#        f        8ff#')
# 438        1r        f       1r      f            8r        f         (8ggL
# 440        1r        f       1r      f            4d        f          2bbt
# 442        1r        f       1r      f            8B        f          2bbt
# 444        8C        f       8E      f            1r        f           4aa
# 446      (8CL        f     (8EL      f            1r        f            4r
# 448      8E')        f     8G')      f            1r        f            2r
# 450    (8F#XL        f     (8AL      f            1r        f            2r
# 453      8A')        f     8c')      f            1r        f            2r
# 455      (8AL        f     (8cL      f            1r        f            2r
# 457       2cT        f      2eT      f            1r        f          (2aT
# 459        4B        f       4d      f           4dd        f           8g)
# 461        4r        f       4r      f            8r        f          (8gL
# 463        2r        f       2r      f            4b        f           8b)
# 465        2r        f       2r      f            8r        f          (8bL
# 466        2r        f       2r      f            8g        f            8r
# 468        2r        f       2r      f            4d        f          8dd)
# 470        2r        f       2r      f            8r        f         (8eeL
# 472        4r        f       4r      f            4B        f          2ggT
# 473        4B        f       4d      f            8r        f          2ggT
# 474        4B        f       4d      f            8G        f          2ggT
# 476      4A#X        f     4c#X      f            1r        f        (2.ff#
# 477     (8A#L        f    (8c#L      f            1r        f        (2.ff#
# 479     [2c#X       sf      [2e     sf            1r        f        (2.ff#
# 480     [2c#X       sf      [2e     sf            1r        f           4gg
# 482     4c#])       sf     4e])     sf            1r       sf         2.ff#
# 483      (8BL       sf     (8dL     sf            1r       sf         2.ff#
# 485        4B       sf       4d     sf            1r       sf         2.ff#
# 486       4G)       sf      4B)     sf            1r       sf         4ee#X
# 488       4F#       sf     4A#X     sf            4r       sf         4ff#)
# 489       4f#       sf   (8a#XL     sf       (8cc#XL       sf        (2fff#
# 491       4f#       sf   [2cc#X     sf          [2ee       sf        (2fff#
# 492       4f#       sf   [2cc#X     sf          [2ee       sf          4ggg
# 494       4f#       sf   4cc#])     sf         4ee])       sf        2.fff#
# 495       4f#       sf     (8bL     sf         (8ddL       sf        2.fff#
# 497       4f#       sf       4b     sf           4dd       sf        2.fff#
# 498       4f#       sf    4g#X)     sf           4b)       sf        4eee#X
# 500       4f#       sf     4a#X     sf         4cc#X       sf        4fff#)
# 501        4r       sf       4r     sf            4r       sf         (2ff#
# 503        2r       sf       2r     sf            2r       sf           4gg
# 505        2r       sf       2r     sf            2r       sf          4een
# 506        2r       sf       2r     sf            2r       sf           4dd
# 507        4r       sf       4r     sf            4r       sf         4cc#X
# 508     (4FF#      p p    (4A#X      p         (4c#X       sf         4ff#)
# 510      4BB)      p p      4B)      p           4d)        p           (4b
# 511        4r      p p       4r      p            4r        p           4dd
# 512      (4BB      p p      (4B      p           (4d        p          4ff#
# 513     4FF#)      p p      4d)      p          4f#)        p           4bb
# 515        2r      p p       2r      p            2r        p         4aa#X
# 516        2r      p p       2r      p            2r        p       4ccc#X)
# 517      (4F#      p p     (4F#      p         (4c#X        p            4r
# 518    4AA#X)      p p      4e)      p          4f#)        p        (4ccc#
# 520        2r      p p       2r      p            2r        p           4bb
# 521        2r      p p       2r      p            2r        p         4ddd)
# 522      (4F#      p p      (4B      p           (4d        p            4r
# 711     (8DDL       pp       4r     pp            1r       pp            1r
# 714    8FFn')       pp       4r     pp            1r       pp            1r
# 716        2r       pp     (8DL     pp            1r       pp            1r
# 718        2r       pp    8Fn')     pp            1r       pp            1r
# 720     (8DDL       pp       4r     pp            1r       pp            1r
# 723    8FFn')       pp       4r     pp            4r       pp            1r
# 725        2r       pp     (8DL     pp          (8dL       pp            1r
# 727        2r       pp    8Fn')     pp         8fn')       pp            1r
# 729     (8DDL       pp       4r     pp            4r       pp            1r
# 732    8FFn')       pp       4r     pp            1r       pp            4r
# 734        2r       pp     (8DL     pp            1r       pp         (8ddL
# 736        2r       pp    8Fn')     pp            1r       pp        8ffn')
# 738     (8DDL       pp       4r     pp            1r       pp            4r
# 741    4FFn')       pp      4Fn     pp            4r       pp            2r
# 742     (8DDL       pp     (8DL     pp          (8dL       pp            2r
# 744     4FF')       pp     4F')     pp         4fn')       pp            4r
# 745     (8DDL       pp     (8DL     pp          (8dL       pp         (8ddL
# 748    4FFn')       pp    4Fn')     pp         4fn')       pp        4ffn')
# 749     (8DDL       pp     (8DL     pp         (8ddL       pp        (8dddL
# 751     4FF')       pp     4F')     pp        4ffn')       pp       4fffn')
# 752     (8DDL       pp     (8DL     pp         (8ddL       pp        (8dddL
# 755    4FFn')       pp    4Fn')     pp        4ffn')       pp       4fffn')
# 756     (8DDL       pp     (8DL     pp            4r       pp            4r
# 758     4FF')       pp     4F')     pp            2r       pp            2r
# 759     (8DDL       pp     (8DL     pp            2r       pp            2r
# 762     8FFnL       pp     8FnL     pp            1r       pp            2r
# 763       8DD       pp       8D     pp            1r       pp            2r
# 764       8EE       pp       8E     pp            1r       pp            2r
# 766      8GGL       pp      8GL     pp            1r       pp            8r
# 767        8r       pp       8r     pp            1r       pp           8GL
# 768       8EE       pp       8E     pp            1r       pp            8A
# 771       4CC       fp       4C     fp            4c       fp           2.c
# 773        8C       fp       8E     fp            8G       fp           2.c
# 774        4C       fp       4E     fp            4G       fp           2.c
# 775        8r       fp       8r     fp            8r       fp        (8cccL
# 776        8C       fp       8E     fp            8G       fp            8r
# 778        4C       fp       4E     fp            4G       fp        4eee')
# 780        8C       fp       8E     fp            8G       fp            8r
# 781        4C       fp      4Fn     fp            4A       fp         4ccc'
# 783        8C       fp       8F     fp            8r       fp          8aa'
# 785        4C       fp       4E     fp            4c       fp          2.gg
# 787        8C       fp       8E     fp            8G       fp          2.gg
# 788        4C       fp       4E     fp            4G       fp          2.gg
# 789        8r       fp       8r     fp            8r       fp        (8cccL
# 790        8C       fp       8E     fp            8G       fp            8r
# 792        4C       fp       4E     fp            4G       fp         8eeeL
# 794        8r       fp       8r     fp            8r       fp         8ccc'
# 795        8C       fp       8E     fp            8G       fp         8bb'J
# 796        4C       fp      4Fn     fp            4A       fp        (8dddL
# 798        8r       fp       8r     fp            8r       fp          8bb'
# 799        8C       fp       8F     fp            8r       fp            8r
# 801        4C       fp       4E     fp            4c       fp          [2gg
# 803        8C       fp       8E     fp            8G       fp          [2gg
# 804        4C       fp       4E     fp            4G       fp         4.gg]
# 806        8C       fp       8E     fp            8G       fp            8r
# 808        4C       fp       4E     fp            4G       fp          4ee'
# 810        8C       fp       8E     fp            8G       fp            8r
# 811        4C       fp       4E     fp            4G       fp          4cc'
# 813        8C       fp       8E     fp            8G       fp            8r
# 815        8C       fp       8E     fp            8G       fp         8qqb/
# 816        4C       fp       4E     fp            4G       fp           (4a
# 817        8r       fp       8r     fp            8r       fp           8gL
# 818        8C       fp       8E     fp            8G       fp            8r
# 819       4BB       fp       4E     fp            4G       fp           [2b
# 821       8BB       fp       8E     fp            8G       fp           [2b
# 823       4BB       fp     4F#X     fp            4A       fp           4b]
# 824        8r       fp       8r     fp            8r       fp       (8cc#XL
# 825       8BB       fp      8F#     fp            8A       fp            8r
# 826       4BB       fp      4F#     fp            4A       fp           4ee
# 827        8r       fp       8r     fp            8r       fp        8ff#XL
# 828       8BB       fp      8F#     fp            8A       fp        8dd#J)
# 830        4E       fp       4E     fp            4G       fp           8ee
# 832        8r       fp       8r     fp            8r       fp         (8eeL
# 833        8E       fp       8G     fp            8g       fp            8r
# 834        4D       fp       4G     fp           4fn       fp          8gg)
# 836        8r       fp       8r     fp            8r       fp         (8aaL
# 837        8D       fp       8G     fp            8f       fp            8r
# 839        4C       fp       4G  fp fp            4e       fp        2.ccc)
# 841        8c       fp       8e  fp fp            8g       fp        2.ccc)
# 842        4c       fp       4e  fp fp            4g       fp        2.ccc)
# 843        8r       fp       8r  fp fp            8r       fp        (8cccL
# 844        8c       fp       8e  fp fp            8g       fp            8r
# 846        4c       fp       4e  fp fp            4g       fp        4eee')
# 848        8c       fp       8e  fp fp            8g       fp            8r
# 849        4c       fp      4fn  fp fp            4a       fp         4ccc'
# 851        8c       fp       8f  fp fp            8r       fp          8aa'
# 853        4c       fp       4e  fp fp           4cc       fp          2.gg
# 855        8c       fp       8e  fp fp            8g       fp          2.gg
# 856        4c       fp       4e  fp fp            4g       fp          2.gg
# 857        8r       fp       8r  fp fp            8r       fp        (8cccL
# 858        8c       fp       8e  fp fp            8g       fp            8r
# 860        4c       fp       4e  fp fp            4g       fp         8eeeL
# 862        8r       fp       8r  fp fp            8r       fp         8ccc'
# 863        8c       fp       8e  fp fp            8g       fp         8bb'J
# 864        4c       fp      4fn  fp fp            4a       fp        (8dddL
# 866        8r       fp       8r  fp fp            8r       fp          8bb'
# 867        8c       fp       8f  fp fp            8r       fp            8r
# 869        4c       fp       4e  fp fp           4cc       fp          [2gg
# 871        8c       fp       8e  fp fp            8g       fp          [2gg
# 872        4c       fp       4e  fp fp            4g       fp         4.gg]
# 874        8c       fp       8e  fp fp            8g       fp            8r
# 876        4c       fp       4e  fp fp            4g       fp          4ee'
# 878        8c       fp       8e  fp fp            8g       fp            8r
# 879        4c       fp       4e  fp fp            4g       fp          4cc'
# 881        8c       fp       8e  fp fp            8g       fp            8r
# 883        8c       fp       8e  fp fp            8g       fp         8qqb/
# 884        4c       fp       4e  fp fp            4g       fp           (4a
# 885        8r       fp       8r  fp fp            8r       fp           8gL
# 886        8c       fp       8e  fp fp            8g       fp            8r
# 887        4B       fp       4e  fp fp            4g       fp           [2b
# 889        8B       fp       8e  fp fp            8g       fp           [2b
# 891        4B       fp     4f#X  fp fp            4a       fp           4b]
# 892        8r       fp       8r  fp fp            8r       fp       (8cc#XL
# 893        8B       fp      8f#  fp fp            8a       fp            8r
# 894        4B       fp      4f#  fp fp            4a       fp           4ee
# 895        8r       fp       8r  fp fp            8r       fp        8ff#XL
# 896        8B       fp      8f#  fp fp            8a       fp        8dd#J)
# 898        4e       fp       4B  fp fp            4g       fp          2ee`
# 900        8E       fp       8B  fp fp            8e       fp          2ee`
# 901        4E       fp       4B  fp fp            4e       fp          2gg`
# 903        8E       fp       8B  fp fp            8e       fp          2gg`
# 905       4F#       fp     4A#X  fp fp          4c#X       fp        2.ff#X
# 907       8F#       fp      8A#  fp fp           8c#       fp        2.ff#X
# 908       4F#       fp      4A#  fp fp           4c#       fp        2.ff#X
# 909        8r       fp       8r  fp fp            8r       fp       4ccc#X'
# 910       8F#       fp      8A#  fp fp           8c#       fp       4ccc#X'
# 912       4F#       fp     4A#X  fp fp          4c#X       fp      (8ccc#XL
# 913       4F#       fp     4A#X  fp fp          4c#X       fp       8aa#XJ)
# 914        8r       fp       8r  fp fp            8r       fp         4ff#'
# 915       8F#       fp      8A#  fp fp           8c#       fp         4ff#'
# 916       4F#       fp      4A#  fp fp           4c#       fp         4ff#'
# 917        8r       fp       8r  fp fp            8r       fp         4ff#'
# 918       8F#       fp      8A#  fp fp           8c#       fp         4ff#'
# 920      2F#`       fp    2A#X`  fp fp         2c#X`       fp         2ff#`
# 921       2D`       fp     2An`  fp fp         2f#X`       fp        2cccn`
# 923       2G`       fp      2d`  fp fp          2fn`       fp          2bb`
# 924      2GG`       fp   2G` 2d  fp fp         2ffn`       fp          2bb`
# 926        4C       fp       4G     fp           4ee       fp         2.ccc
# 928    8CC 8C       fp    8E 8G     fp            8g       fp         2.ccc
# 929    4CC 4C       fp    4E 4G     fp            4g       fp         2.ccc
# 930        8r       fp       8r     fp            8r       fp        (8cccL
# 931    8CC 8C       fp    8E 8G     fp            8g       fp            8r
# 933    4CC 4C       fp    4E 4G     fp            4g       fp        4eee')
# 935    8CC 8C       fp    8E 8G     fp            8g       fp            8r
# 936    4CC 4C       fp   4Fn 4A     fp            4a       fp         4ccc'
# 938    8CC 8C       fp       8F     fp            8r       fp          8aa'
# 940    4CC 4C       fp       4E     fp           4cc       fp          2.gg
# 942    8CC 8C       fp    8E 8G     fp            8g       fp          2.gg
# 943    4CC 4C       fp    4E 4G     fp            4g       fp          2.gg
# 944        8r       fp       8r     fp            8r       fp        (8cccL
# 945    8CC 8C       fp    8E 8G     fp            8g       fp            8r
# ...
# 2363    pp         i64  2441    1    =335   e  M2/2
# 2366    pp         i64  2444    3    =335   e  M2/2
# 2367    pp         i64  2446    4    =335   e  M2/2
# 2370    pp       #viio  2450    1    =336   e  M2/2
# 2371    pp       #viio  2451    2    =336   e  M2/2
# 2373    pp       #viio  2453    3    =336   e  M2/2
# 2375    pp       #viio  2456    4    =336   e  M2/2
# 2378    pp      #viio6  2460    1    =337   e  M2/2
# 2379    pp      #viio6  2461    2    =337   e  M2/2
# 2381    pp      #viio6  2463    3    =337   e  M2/2
# 2382    pp      #viio6  2464    4    =337   e  M2/2
# 2385    pp           i  2467    1    =338   e  M2/2
# 2386    pp           i  2468    2    =338   e  M2/2
# 2388    pp           i  2470    3    =338   e  M2/2
# 2389    pp           i  2471    4    =338   e  M2/2
# 2392    pp          i6  2474    1    =339   e  M2/2
# 2393    pp          i6  2475    2    =339   e  M2/2
# 2395    pp          i6  2477    3    =339   e  M2/2
# 2396    pp          i6  2478    4    =339   e  M2/2
# 2399    pp       .bII6  2482    1    =340   e  M2/2
# 2403    pp       .bII6  2486    3    =340   e  M2/2
# 2404    pp       .bII6  2488    4    =340   e  M2/2
# 2407    pp       .bII6  2491    1    =341   e  M2/2
# 2410    pp       .bII6  2494    3    =341   e  M2/2
# 2411    pp       .bII6  2496    4    =341   e  M2/2
# 2414    ff       .bII6  2499    1    =342   e  M2/2
# 2417    ff       .bII6  2502    3    =342   e  M2/2
# 2422    ff         V[V  2508    1    =344   e  M2/2
# 2423    ff         V[V  2509    2    =344   e  M2/2
# 2425    ff         V[V  2511    3    =344   e  M2/2
# 2426    ff         V[V  2512    4    =344   e  M2/2
# 2427    ff         V[V  2513  4.5    =344   e  M2/2
# 2429    ff          i6  2516    1    =345   e  M2/2
# 2430    ff          i6  2517    2    =345   e  M2/2
# 2431    ff          i6  2518    3    =345   e  M2/2
# 2432    ff          i6  2519    4    =345   e  M2/2
# 2434    ff         V64  2522    1    =346   e  M2/2
# 2435    ff         V64  2523    3    =346   e  M2/2
# 2437    ff         i6]  2525    1    =347   e  M2/2
# 2438    ff      V2/bII  2526    3    =347   e  M2/2
# 2439    ff      V2/bII  2527    4    =347   e  M2/2
# 2442     f       .bII6  2530    1    =348   e  M2/2
# 2445     f       .bII6  2533    3    =348   e  M2/2
# 2446     f       .bII6  2534    4    =348   e  M2/2
# 2449     f       .bII6  2537    1    =349   e  M2/2
# 2452     f       .bII6  2540    3    =349   e  M2/2
# 2453     f       .bII6  2541    4    =349   e  M2/2
# 2456    ff       .bII6  2544    1    =350   e  M2/2
# 2459    ff       .bII6  2547    3    =350   e  M2/2
# 2464    ff         V[V  2553    1    =352   e  M2/2
# 2465    ff         V[V  2554    2    =352   e  M2/2
# 2467    ff         V[V  2556    3    =352   e  M2/2
# 2468    ff         V[V  2557    4    =352   e  M2/2
# 2469    ff         V[V  2558  4.5    =352   e  M2/2
# 2471    ff          i6  2561    1    =353   e  M2/2
# 2472    ff          i6  2562    2    =353   e  M2/2
# 2473    ff          i6  2563    3    =353   e  M2/2
# 2474    ff          i6  2564    4    =353   e  M2/2
# 2476    ff          i6  2566    1    =354   e  M2/2
# 2477    ff          V6  2567    3    =354   e  M2/2
# 2479    ff         i6]  2570    1    =355   e  M2/2
# 2480    ff      V2/bII  2571    3    =355   e  M2/2
# 2482    ff       .bII6  2573    1    =356   e  M2/2
# 2483    ff       V2/bI  2574    3    =356   e  M2/2
# 2485    ff        .bI6  2576    1    =357   e  M2/2
# 2486    ff    .Ger6/bv  2577    3    =357   e  M2/2
# 2488    ff       .bv64  2579    1    =358   e  M2/2
# 2489    sf        V2/V  2580    3    =358   e  M2/2
# 2491    >]         V65  2582    1    =359   e  M2/2
# 2492    >]         V65  2583    3    =359   e  M2/2
# 2494     p        i(9)  2585    1    =360   e  M2/2
# 2495     p        i(9)  2586    2    =360   e  M2/2
# 2496     p         i\\  2587    3    =360   e  M2/2
# 2497     p         i\\  2588    4    =360   e  M2/2
# 2499     p          VI  2591    1    =361   e  M2/2
# 2500     p          VI  2592    2    =361   e  M2/2
# 2501     p          VI  2594    3    =361   e  M2/2
# 2502     p          VI  2595    4    =361   e  M2/2
# 2504     p       ii%65  2597    1    =362   e  M2/2
# 2505     p       ii%65  2598    2    =362   e  M2/2
# 2506     p       ii%65  2599    3    =362   e  M2/2
# 2507     p       ii%65  2600    4    =362   e  M2/2
# 2509     p           V  2602    1    =363   e  M2/2
# 2510     p           V  2603    2    =363   e  M2/2
# 2511     p           V  2604    3    =363   e  M2/2
# 2512     p           V  2605    4    =363   e  M2/2
# 2514     p         i\\  2607    1    =364   e  M2/2
# 2515     p         i\\  2608  1.5    =364   e  M2/2
# 2516     p         i\\  2609    2    =364   e  M2/2
# 2517     p         i\\  2610  2.5    =364   e  M2/2
# 2518     p         i\\  2611    3    =364   e  M2/2
# 2519     p         i\\  2612  3.5    =364   e  M2/2
# 2520     p         i\\  2613    4    =364   e  M2/2
# 2521     p         i\\  2614  4.5    =364   e  M2/2
# 2523     p          VI  2617    1    =365   e  M2/2
# 2524     p          VI  2618  1.5    =365   e  M2/2
# 2525     p          VI  2619    2    =365   e  M2/2
# 2526     p          VI  2620  2.5    =365   e  M2/2
# 2527     p          VI  2624    3    =365   e  M2/2
# 2528     p          VI  2625  3.5    =365   e  M2/2
# 2529     p          VI  2626    4    =365   e  M2/2
# 2530     p          VI  2627  4.5    =365   e  M2/2
# 2532     p       ii%65  2629    1    =366   e  M2/2
# 2533     p       ii%65  2630  1.5    =366   e  M2/2
# 2534     p       ii%65  2631    2    =366   e  M2/2
# 2535     p       ii%65  2632  2.5    =366   e  M2/2
# 2536     p       ii%65  2633    3    =366   e  M2/2
# 2537     p       ii%65  2634  3.5    =366   e  M2/2
# 2538     p       ii%65  2635    4    =366   e  M2/2
# 2539     p       ii%65  2636  4.5    =366   e  M2/2
# 2541     p           V  2638    1    =367   e  M2/2
# 2542     p           V  2639  1.5    =367   e  M2/2
# 2543     p           V  2640    2    =367   e  M2/2
# 2544     p           V  2641  2.5    =367   e  M2/2
# 2545     p           V  2642    3    =367   e  M2/2
# 2546     p           V  2643  3.5    =367   e  M2/2
# 2547     p           V  2644    4    =367   e  M2/2
# 2548     p           V  2645  4.5    =367   e  M2/2
# 2550     p         i\\  2648    1    =368   e  M2/2
# 2551     p         i\\  2649  1.5    =368   e  M2/2
# 2552     p         i\\  2650    2    =368   e  M2/2
# 2553     p         i\\  2651  2.5    =368   e  M2/2
# 2554     p           i  2652    3    =368   e  M2/2
# 2555     p           i  2653  3.5    =368   e  M2/2
# 2556     p           i  2654    4    =368   e  M2/2
# 2557     p           i  2655  4.5    =368   e  M2/2
# 2559     p           i  2657    1    =369   e  M2/2
# 2560     p           i  2658  1.5    =369   e  M2/2
# 2561     p           i  2659    2    =369   e  M2/2
# 2562     p           i  2660  2.5    =369   e  M2/2
# 2563     p           i  2661    3    =369   e  M2/2
# 2564     p           i  2662  3.5    =369   e  M2/2
# 2565     p           i  2663    4    =369   e  M2/2
# 2566     p           i  2664  4.5    =369   e  M2/2
# 2568     p      VI.V43  2666    1    =370   e  M2/2
# 2569     p      VI.V43  2667  1.5    =370   e  M2/2
# 2570     p      VI.V43  2668    2    =370   e  M2/2
# 2571     p      VI.V43  2669  2.5    =370   e  M2/2
# 2572     p      VI.V43  2670    3    =370   e  M2/2
# 2573     p      VI.V43  2671  3.5    =370   e  M2/2
# 2574     p      VI.V43  2672    4    =370   e  M2/2
# 2575     p      VI.V43  2673  4.5    =370   e  M2/2
# 2577     p          V7  2675    1    =371   e  M2/2
# 2578     p          V7  2676  1.5    =371   e  M2/2
# 2579     p          V7  2677    2    =371   e  M2/2
# 2580     p          V7  2678  2.5    =371   e  M2/2
# 2581     p          V7  2679    3    =371   e  M2/2
# 2582     p          V7  2680  3.5    =371   e  M2/2
# 2583     p          V7  2681    4    =371   e  M2/2
# 2584     p          V7  2682  4.5    =371   e  M2/2
# 2586    ff           I  2688    1    =372   e  M2/2
# 2588    ff           I  2690  2.5    =372   e  M2/2
# 2589    ff           I  2691    3    =372   e  M2/2
# 2590    ff           I  2692    4    =372   e  M2/2
# 2591    ff           I  2693  4.5    =372   e  M2/2
# 2593    ff           I  2696    1    =373   e  M2/2
# 2595    ff           I  2698  2.5    =373   e  M2/2
# 2596    ff       I(64)  2699    3    =373   e  M2/2
# 2598    ff       I(64)  2701  4.5    =373   e  M2/2
# 2600    ff           I  2703    1    =374   e  M2/2
# 2602    ff           I  2705  2.5    =374   e  M2/2
# 2603    ff           I  2706    3    =374   e  M2/2
# 2604    ff           I  2707    4    =374   e  M2/2
# 2605    ff           I  2708  4.5    =374   e  M2/2
# 2607    ff           I  2710    1    =375   e  M2/2
# 2609    ff           I  2712    2    =375   e  M2/2
# 2610    ff           I  2713  2.5    =375   e  M2/2
# 2611    ff       I(64)  2714    3    =375   e  M2/2
# 2613    ff       I(64)  2716    4    =375   e  M2/2
# 2614    ff       I(64)  2717  4.5    =375   e  M2/2
# 2616    ff        I[I6  2719    1    =376   e  M2/2
# 2618    ff        I[I6  2721  2.5    =376   e  M2/2
# 2619    ff        I[I6  2722    3    =376   e  M2/2
# 2621    ff         ii7  2724  4.5    =376   e  M2/2
# 2623    ff           I  2726    1    =377   e  M2/2
# 2625    ff         ii7  2728  2.5    =377   e  M2/2
# 2626    ff          I6  2729    3    =377   e  M2/2
# 2628    ff        iii]  2731  4.5    =377   e  M2/2
# 2630    ff       i.iv6  2733    1    =378   e  M2/2
# 2631    ff       i.iv6  2734    1    =378   e  M2/2
# 2632    ff       i.iv6  2735    2    =378   e  M2/2
# 2633    ff       i.iv6  2736  2.5    =378   e  M2/2
# 2634    ff           V  2737    3    =378   e  M2/2
# 2636    ff           V  2739  4.5    =378   e  M2/2
# 2638    ff           V  2741    1    =379   e  M2/2
# 2639    ff           V  2742    2    =379   e  M2/2
# 2640    ff           V  2743  2.5    =379   e  M2/2
# 2641    ff       V2(2)  2744    3    =379   e  M2/2
# 2643    ff       V2(2)  2746  4.5    =379   e  M2/2
# 2645    ff       V2(2)  2748    1    =380   e  M2/2
# 2646    ff          V2  2749    2    =380   e  M2/2
# 2647    ff          V2  2750  2.5    =380   e  M2/2
# 2648    ff          i6  2751    3    =380   e  M2/2
# 2650    ff          i6  2753    4    =380   e  M2/2
# 2651    ff          i6  2754  4.5    =380   e  M2/2
# 2653    ff     #viio64  2756    1    =381   e  M2/2
# 2655    ff     #viio64  2758    2    =381   e  M2/2
# 2656    ff     #viio64  2759  2.5    =381   e  M2/2
# 2657    ff           i  2760    3    =381   e  M2/2
# 2659    ff           i  2762    4    =381   e  M2/2
# 2660    ff           i  2763  4.5    =381   e  M2/2
# 2662    ff         iv6  2765    1    =382   e  M2/2
# 2664    ff         iv6  2767    2    =382   e  M2/2
# 2665    ff         iv6  2768  2.5    =382   e  M2/2
# 2666    ff   #viio6/iv  2769    3    =382   e  M2/2
# 2668    ff   #viio6/iv  2771    4    =382   e  M2/2
# 2669    ff   #viio6/iv  2772  4.5    =382   e  M2/2
# 2671    ff          iv  2774    1    =383   e  M2/2
# 2672    ff          iv  2775    2    =383   e  M2/2
# 2673    ff        iio6  2776  2.5    =383   e  M2/2
# 2674    ff          V7  2777    3    =383   e  M2/2
# 2675    ff          V7  2778    4    =383   e  M2/2
# 2676    ff          V7  2779  4.5    =383   e  M2/2
# 2678    sf         i\\  2782    1    =384   e  M2/2
# 2680    sf           i  2784  2.5    =384   e  M2/2
# 2681    sf       i(64)  2785    3    =384   e  M2/2
# 2683    sf       i(64)  2787  4.5    =384   e  M2/2
# 2685    sf           i  2789    1    =385   e  M2/2
# 2688    sf           i  2792    3    =385   e  M2/2
# 2690    sf           i  2794  4.5    =385   e  M2/2
# 2692    sf           i  2796    1    =386   e  M2/2
# 2694    sf           i  2798  2.5    =386   e  M2/2
# 2695    sf       i(64)  2799    3    =386   e  M2/2
# 2697    sf       i(64)  2801  4.5    =386   e  M2/2
# 2699    sf           i  2803    1    =387   e  M2/2
# 2702    sf           i  2806    3    =387   e  M2/2
# 2704    sf           i  2808  4.5    =387   e  M2/2
# 2706    sf           i  2810    1    =388   e  M2/2
# 2708    sf           i  2812  2.5    =388   e  M2/2
# 2709    sf           i  2813    3    =388   e  M2/2
# 2711    sf      i(6+4)  2815  4.5    =388   e  M2/2
# 2713    sf           i  2817    1    =389   e  M2/2
# 2717    sf           i  2821    3    =389   e  M2/2
# 2719    sf           i  2823  4.5    =389   e  M2/2
# 2721    sf           i  2825    1    =390   e  M2/2
# 2723    sf           i  2827  2.5    =390   e  M2/2
# 2724    sf           i  2828    3    =390   e  M2/2
# 2726    sf      i(6+4)  2830  4.5    =390   e  M2/2
# 2728    sf           i  2832    1    =391   e  M2/2
# 2731    sf           i  2835    3    =391   e  M2/2
# 2733    sf       i(64)  2837  4.5    =391   e  M2/2
# 2735    sf           i  2840    1    =392   e  M2/2
# 2738    sf           i  2843    3    =392   e  M2/2
# 2740    sf          V7  2845  4.5    =392   e  M2/2
# 2742    sf           i  2848    1    =393   e  M2/2
# 2744    sf           i  2850  2.5    =393   e  M2/2
# 2745    sf           i  2851    3    =393   e  M2/2
# 2747    sf          V7  2853  4.5    =393   e  M2/2
# 2749    sf           i  2856    1    =394   e  M2/2
# 2752    sf           i  2859    3    =394   e  M2/2
# 2754    sf          V7  2862  4.5    =394   e  M2/2
# 2756    sf           i  2864    1    =395   e  M2/2
# 2759    sf           i  2867    3    =395   e  M2/2
# 2761    sf      V7/bII  2869  4.5    =395   e  M2/2
# 2763    sf        .bII  2871    1    =396   e  M2/2
# 2766    sf        .bII  2874    3    =396   e  M2/2
# 2768    sf      V7/III  2876  4.5    =396   e  M2/2
# 2770    sf         III  2878    1    =397   e  M2/2
# 2772    sf       V7/iv  2880  2.5    =397   e  M2/2
# 2773    sf          iv  2881    3    =397   e  M2/2
# 2775    sf        V7/v  2883  4.5    =397   e  M2/2
# 2777    sf           v  2885    1    =398   e  M2/2
# 2779    sf       V7/VI  2887  2.5    =398   e  M2/2
# 2780    sf          VI  2888    3    =398   e  M2/2
# 2782    sf      V7/vii  2890  4.5    =398   e  M2/2
# 2784    sf         vii  2892    1    =399   e  M2/2
# 2786    sf          V7  2894  2.5    =399   e  M2/2
# 2787    sf           i  2895    3    =399   e  M2/2
# 2789    sf          V7  2897  4.5    =399   e  M2/2
# 2791    sf           i  2899    1    =400   e  M2/2
# 2793    sf          V7  2901  2.5    =400   e  M2/2
# 2794    sf           i  2902    3    =400   e  M2/2
# 2796    sf          V7  2904  4.5    =400   e  M2/2
# 2798    sf           i  2906    1    =401   e  M2/2
# 2800    sf           V  2908  2.5    =401   e  M2/2
# 2801    sf           i  2909    3    =401   e  M2/2
# 2803    sf           V  2911  4.5    =401   e  M2/2
# 2805    sf           i  2913    1    =402   e  M2/2
# 2807    sf           V  2915  2.5    =402   e  M2/2
# 2808    sf           i  2916    3    =402   e  M2/2
# 2810    sf           V  2918  4.5    =402   e  M2/2
# 2812    sf           i  2920    1    =403   e  M2/2
# 2814    sf           V  2922  2.5    =403   e  M2/2
# 2815    sf           i  2923    3    =403   e  M2/2
# 2817    sf           V  2925  4.5    =403   e  M2/2
# 2819    sf           i  2927    1    =404   e  M2/2
# 2821    sf           V  2929  2.5    =404   e  M2/2
# 2822    sf           i  2930    3    =404   e  M2/2
# 2824    sf           V  2932  4.5    =404   e  M2/2
# 2826    sf           i  2934    1    =405   e  M2/2
# 2828    sf          V7  2936    3    =405   e  M2/2
# 2831    sf           i  2939    1    =406   e  M2/2
# 2833    sf          V7  2941    3    =406   e  M2/2
# 2836    sf           i  2944    1    =407   e  M2/2
# 2840    sf           V  2948    1    =408   e  M2/2
# 2844    sf         i\\  2952    1    =409   e  M2/2

# %%
prev_note_list = []
for index, row in df.iterrows():
    # for this onset slice 
    this_onset_vec = []
    
    ######################################### Process notes and onsets ########################################
    voices = ["voice4","voice3","voice2","voice1"]
    cur_note_tmp = []
    for v in voices:
        this_note = ''.join(row[[v]].values)
        if ' ' in this_note: #for a part has multiple voices
            this_note_list = this_note.split(" ")
            cur_note_tmp.extend(this_note_list)
        else:
            cur_note_tmp.append(this_note)
    
    cur_note_list = []
    for n in cur_note_tmp:
        note_name = re.sub('[^a-gA-G#-]+', '', n)
        if note_name:
            cur_note_list.append(note_name)
            
    cur_onset_list = list(set(cur_note_list) - set(prev_note_list))
    prev_note_list = cur_note_list
    
    
    note_vec = to_21d_vec(cur_note_list)
    onset_vec = to_21d_vec(cur_onset_list)
    this_onset_vec.extend(note_vec)
    this_onset_vec.extend(onset_vec)
    
    ######################################### Process beat position ########################################
    beat_pos = ''.join(row[["beat"]].values)
    meter = ''.join(row[["meter"]].values)
    meter = meter.replace("M", "")
    beat_vec = get_beat_vector(beat_pos, meter)
    this_onset_vec.extend(beat_vec)
    
    ######################################### Process chord label ########################################
    harm = ''.join(row[["harm"]].values)
    harm = re.sub('[()]', '', harm) # process string
    harm = specialChords(harm)
    harm = specialChordsABC(harm)
    key = ''.join(row[["key"]].values)
    key_harm = key + ":" + harm
    #print(key_harm)
    try:
        chord_label = inputRN(key_harm)["Chord label"]
    except:
        continue # pass this onset slice if RN is not recognizable
    this_onset_vec.append(str(chord_label))
    #print(this_onset_vec)
  
    #########################################################################################################
# Out:
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:vii%43
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:vii%43
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:I62
# Invalid entry. Try again. e:bV/iio
# Invalid entry. Try again. e:bV/iio
# Invalid entry. Try again. e:bV/iio
# Invalid entry. Try again. e:bVII4
# Invalid entry. Try again. e:bVII4
# Invalid entry. Try again. e:V9
# Invalid entry. Try again. e:V9
# Invalid entry. Try again. e:V9
# Invalid entry. Try again. e:V9
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:#viio2
# Invalid entry. Try again. e:V74
# Invalid entry. Try again. e:i/VIM
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:bIII2
# Invalid entry. Try again. e:bIII2
# Invalid entry. Try again. e:i9
# Invalid entry. Try again. e:i9
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:ii%65
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:V22
# Invalid entry. Try again. e:i6+4
# Invalid entry. Try again. e:i6+4

# %%
print(inputRN ("G:bII6"))
# Out:
# {'Current key': 'G major', 'Tonicized key': 'None', 'Intervallic construction': 'AbM3P5', 'Inversion': '1', 'Chord label': 'Ab major', 'Default function': 'subdominant', 'Chord pitches': "('Ab', 'C', 'Eb')", 'Chord pitch classes': '(8, 0, 3)'}
